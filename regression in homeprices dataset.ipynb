# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\MLCLS\homeprices.csv')

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
sns.regplot(x='area',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
x=df.drop('price',axis=1)

# %%
y=df.drop('area',axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
brain=LinearRegression()

# %%
brain.fit(x,y)
# Out:
# LinearRegression()

# %%
brain.score(x,y)
# Out:
# 0.9940397303173175

# %%
brain.predict([])
